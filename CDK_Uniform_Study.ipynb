# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
CDK=pd.read_csv('D:\DS_Study\Data_sets\CDK.csv')
CDK
# Out:
#       No                  NAMES     VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 0      1      DUKUNDE Henriette   Soprano     Member        Yes        Yes
# 1      2  DUKUZE MUGENZI Vivine   Soprano     Member        Yes        Yes
# 2      3   HITIYAREMYE Clotilde   Soprano     Member        Yes        Yes
# 3      4         IGIHOZO Regine  Soprano-     Member        Yes        Yes
# 4      5       IKIBASUMBA Diane   Soprano     Member        Yes        Yes
# ..   ...                    ...       ...        ...        ...        ...
# 115  116     UWIRAGIYE Clémence      Alto     Member         No        Yes
# 116  117      UWIRAGIYE Vestine      Alto     Member        Yes        Yes
# 117  118      UWONKUNDA Fabiola      Alto        New        yes        yes
# 118  119        TUYUBAHE Yvette   Soprano        New         No        Yes
# 119  120     UWIZEYE Christelle      Alto        NaN         No         No
#
# ...

# %%
CDK.head()
# Out:
#    No                  NAMES     VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 0   1      DUKUNDE Henriette   Soprano     Member        Yes        Yes
# 1   2  DUKUZE MUGENZI Vivine   Soprano     Member        Yes        Yes
# 2   3   HITIYAREMYE Clotilde   Soprano     Member        Yes        Yes
# 3   4         IGIHOZO Regine  Soprano-     Member        Yes        Yes
# 4   5       IKIBASUMBA Diane   Soprano     Member        Yes        Yes
#
#   UMUMBRATA_CCC2017 FUNICULI_CCC2018 SEKIBI_CCC2019     UN_OPERA  \
# 0               Yes              Yes            Yes          Yes
# 1               Yes              Yes            Yes          Yes
# 2               Yes              Yes            Yes          Yes
# 3               Yes              Yes            Yes          Yes
# 4               Yes              Yes            Yes  Incomplete
#
#   BYAMATE_CCC2021 REQUIEM (all black)    STATUS
# 0              No                 Yes  Inactive
# ...

# %%
CDK.shape
# Out:
# (120, 13)

# %%
CDK.index
# Out:
# RangeIndex(start=0, stop=120, step=1)

# %%
CDK.columns
# Out:
# Index(['No', 'NAMES', 'VOICE', 'MEMBERSHIP', 'UN_CCC2014', 'UN_CCC2016',
#        'UMUMBRATA_CCC2017', 'FUNICULI_CCC2018', 'SEKIBI_CCC2019', 'UN_OPERA',
#        'BYAMATE_CCC2021', 'REQUIEM (all black)', 'STATUS'],
#       dtype='object')

# %%
CDK.dtypes
# Out:
# No                      int64
# NAMES                  object
# VOICE                  object
# MEMBERSHIP             object
# UN_CCC2014             object
# UN_CCC2016             object
# UMUMBRATA_CCC2017      object
# FUNICULI_CCC2018       object
# SEKIBI_CCC2019         object
# UN_OPERA               object
# BYAMATE_CCC2021        object
# REQUIEM (all black)    object
# STATUS                 object
# dtype: object

# %%
CDK.nunique()
# Out:
# No                     120
# NAMES                  120
# VOICE                    5
# MEMBERSHIP               2
# UN_CCC2014               9
# UN_CCC2016              10
# UMUMBRATA_CCC2017       13
# FUNICULI_CCC2018        12
# SEKIBI_CCC2019           9
# UN_OPERA                 9
# BYAMATE_CCC2021         10
# REQUIEM (all black)      7
# STATUS                  17
# dtype: int64

# %%
CDK.replace({'STATUS':{'Inactive':'Non active','non active':'Non active','active ':'Active','Actif':'Active','yes':'Active','Non-active':'Non active','Non Actif':'Non active','Non-active':'Non active','Not Actve':'Non active','Non actif':'Non active','Non sctive':'Non active','requested permission':'Non active','Requested permission':'Non active','active':'Active','Non Active':'Non active','Not Active':'Non active','Active ':'Active'}},inplace=True)
CDK['STATUS'].value_counts()
# Out:
# Active        65
# Non active    16
# Name: STATUS, dtype: int64

# %%
CDK.replace({'UMUMBRATA_CCC2017':{'yes but not fitting':'Not fitting','Not fitting ':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fiting':'Not fitting ','ok not fitting ':'Not fitting','N0':'No','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['UMUMBRATA_CCC2017'].value_counts()
# Out:
# Yes            76
# No             30
# Not fitting     5
# Incomplete      1
# Name: UMUMBRATA_CCC2017, dtype: int64

# %%
CDK['UN_CCC2014'].value_counts()
# Out:
# No            45
# Yes           28
# yes           19
# no             9
# YES            4
# Incomplete     2
# Yes            1
# Yew            1
# NO             1
# Name: UN_CCC2014, dtype: int64

# %%
CDK['UN_CCC2016'].value_counts()
# Out:
# Yes                    35
# No                     31
# yes                    28
# no                      6
# Not fitting             4
# YES                     2
# Incomplete              2
# NO                      1
# not fitting             1
# Old and not fitting     1
# Name: UN_CCC2016, dtype: int64

# %%
CDK.replace({'UN_CCC2016':{'Old and not fitting':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['UN_CCC2016'].value_counts()
# Out:
# Yes            65
# No             38
# Not fitting     6
# Incomplete      2
# Name: UN_CCC2016, dtype: int64

# %%
CDK['FUNICULI_CCC2018'].value_counts()
# Out:
# Yes              58
# yes              31
# No               16
# no                4
# YES               2
# Not fitting       2
# NO                1
# Not fitting       1
# Yes but small     1
# Not Fitting       1
# ok                1
# incomplete        1
# Name: FUNICULI_CCC2018, dtype: int64

# %%
CDK.replace({'FUNICULI_CCC2018':{'Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['FUNICULI_CCC2018'].value_counts()
# Out:
# Yes            92
# No             21
# Not fitting     5
# Incomplete      1
# Name: FUNICULI_CCC2018, dtype: int64

# %%
CDK['SEKIBI_CCC2019'].value_counts()
# Out:
# Yes           63
# yes           33
# No            13
# no             3
# YES            2
# Incomplete     1
# no pant        1
# Yes            1
# incomplete     1
# Name: SEKIBI_CCC2019, dtype: int64

# %%
CDK.replace({'SEKIBI_CCC2019':{'Yes ':'Yes','no pant':'Incomplete','Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['SEKIBI_CCC2019'].value_counts()
# Out:
# Yes           99
# No            16
# Incomplete     3
# Name: SEKIBI_CCC2019, dtype: int64

# %%
CDK['VOICE'].value_counts()
# Out:
# Soprano     36
# Alto        30
# Basse       27
# Tenor       26
# Soprano-     1
# Name: VOICE, dtype: int64

# %%
CDK.replace({'VOICE':{'Soprano-':'Soprano'}},inplace=True)
CDK['VOICE'].value_counts()
# Out:
# Soprano    37
# Alto       30
# Basse      27
# Tenor      26
# Name: VOICE, dtype: int64

# %%
CDK['UN_OPERA'].value_counts()
# Out:
# Yes            39
# yes            19
# No              8
# no              4
# Incomplete      3
# YES             3
# Incomplete      1
# Yes             1
# N/Aq            1
# Name: UN_OPERA, dtype: int64

# %%
CDK.replace({'UN_OPERA':{'N/Aq':'Yes','Incomplete ':'Incomplete','Yes ':'Yes','no pant':'Incomplete','Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['UN_OPERA'].value_counts()
# Out:
# Yes           63
# No            12
# Incomplete     4
# Name: UN_OPERA, dtype: int64

# %%
CDK['BYAMATE_CCC2021'].value_counts()
# Out:
# Yes           96
# No            19
# Incomplete     2
# Name: BYAMATE_CCC2021, dtype: int64

# %%
CDK.replace({'BYAMATE_CCC2021':{'Yes (Incomplete)':'Incomplete','Yes ':'Yes','no pant':'Incomplete','Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['BYAMATE_CCC2021'].value_counts()
# Out:
# Yes           96
# No            19
# Incomplete     2
# Name: BYAMATE_CCC2021, dtype: int64

# %%
CDK['REQUIEM (all black)'].value_counts()
# Out:
# Yes           75
# yes           31
# No             3
# no             2
# YES            2
# Incomplete     1
# ok             1
# Name: REQUIEM (all black), dtype: int64

# %%
CDK.replace({'REQUIEM (all black)':{'Yes (Incomplete)':'Incomplete','Yes ':'Yes','no pant':'Incomplete','Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['REQUIEM (all black)'].value_counts()
# Out:
# Yes           109
# No              5
# Incomplete      1
# Name: REQUIEM (all black), dtype: int64

# %%
Tenor= CDK.groupby('VOICE').get_group('Tenor')
Tenor
# Out:
#     No                         NAMES  VOICE MEMBERSHIP  UN_CCC2014  \
# 36  37  Abbé MANIRAHO Jean Damascène  Tenor     Member          No
# 37  38              BIGANGO Valentin  Tenor     Member          No
# 38  39               BIJYIMBU Fidèle  Tenor     Member         Yes
# 39  40             GATETE Christophe  Tenor     Member          No
# 40  41           HAKIZIMANA N Cedric  Tenor     Member         yes
# 41  42            HODARI Jean Claude  Tenor     Member         yes
# 42  43                IRAMBONA Oscar  Tenor     Member         Yes
# 43  44               KALISA Emmanuel  Tenor     Member         NaN
# 44  45            KARINGANIRE Phocas  Tenor     Member          no
# 45  46               MANISHIMWE Eric  Tenor     Member         NaN
# 46  47          MBERABAGABO Emmanuel  Tenor     Member         NaN
# 47  48             MICOMYIZA Placide  Tenor     Member         YES
# 48  49                MUHIRE Hilaire  Tenor     Member         yes
# ...

# %%
Soprano= CDK.groupby('VOICE').get_group('Soprano')
Soprano
# Out:
#       No                         NAMES    VOICE MEMBERSHIP UN_CCC2014  \
# 0      1             DUKUNDE Henriette  Soprano     Member        Yes
# 1      2         DUKUZE MUGENZI Vivine  Soprano     Member        Yes
# 2      3          HITIYAREMYE Clotilde  Soprano     Member        Yes
# 3      4                IGIHOZO Regine  Soprano     Member        Yes
# 4      5              IKIBASUMBA Diane  Soprano     Member        Yes
# 5      6         INGABIRE Marie Gratia  Soprano     Member         No
# 6      7             IRADUKUNDA Rosine  Soprano     Member         No
# 7      8               ISHIMWE Cynthia  Soprano     Member         No
# 8      9           ISHIMWE Marie Grâce  Soprano     Member         No
# 9     10           ISHIMWE Marie Aimée  Soprano     Member         No
# 10    11               IZABAYO Liliane  Soprano     Member         No
# 11    12            KAMARABA Illuminee  Soprano     Member         No
# ...

# %%
CDK.isnull()
# Out:
#         No  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0    False  False  False       False       False       False
# 1    False  False  False       False       False       False
# 2    False  False  False       False       False       False
# 3    False  False  False       False       False       False
# 4    False  False  False       False       False       False
# ..     ...    ...    ...         ...         ...         ...
# 115  False  False  False       False       False       False
# 116  False  False  False       False       False       False
# 117  False  False  False       False       False       False
# 118  False  False  False       False       False       False
# 119  False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
CDK.isna()
# Out:
#         No  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0    False  False  False       False       False       False
# 1    False  False  False       False       False       False
# 2    False  False  False       False       False       False
# 3    False  False  False       False       False       False
# 4    False  False  False       False       False       False
# ..     ...    ...    ...         ...         ...         ...
# 115  False  False  False       False       False       False
# 116  False  False  False       False       False       False
# 117  False  False  False       False       False       False
# 118  False  False  False       False       False       False
# 119  False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
CDK.groupby('STATUS').get_group('Active')
# Out:
#       No                  NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 4      5       IKIBASUMBA Diane  Soprano     Member        Yes        Yes
# 5      6  INGABIRE Marie Gratia  Soprano     Member         No         No
# 6      7      IRADUKUNDA Rosine  Soprano     Member         No         No
# 7      8        ISHIMWE Cynthia  Soprano     Member         No         No
# 8      9    ISHIMWE Marie Grâce  Soprano     Member         No         No
# ..   ...                    ...      ...        ...        ...        ...
# 114  115  UWINGABIYE Alphonsine     Alto     Member         No        Yes
# 115  116     UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116  117      UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 118  119        TUYUBAHE Yvette  Soprano        New         No        Yes
# 119  120     UWIZEYE Christelle     Alto        NaN         No         No
#
#     UMUMBRATA_CCC2017 FUNICULI_CCC2018 SEKIBI_CCC2019    UN_OPERA  \
# ...

# %%
CDK['STATUS'].value_counts()
# Out:
# Active        65
# Non active    16
# Name: STATUS, dtype: int64

# %%
CDK.dtypes
# Out:
# No                      int64
# NAMES                  object
# VOICE                  object
# MEMBERSHIP             object
# UN_CCC2014             object
# UN_CCC2016             object
# UMUMBRATA_CCC2017      object
# FUNICULI_CCC2018       object
# SEKIBI_CCC2019         object
# UN_OPERA               object
# BYAMATE_CCC2021        object
# REQUIEM (all black)    object
# STATUS                 object
# dtype: object

# %%
CDK.rename(columns={'No':'Number'},inplace=True)
CDK
# Out:
#      Number                  NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 0         1      DUKUNDE Henriette  Soprano     Member        Yes        Yes
# 1         2  DUKUZE MUGENZI Vivine  Soprano     Member        Yes        Yes
# 2         3   HITIYAREMYE Clotilde  Soprano     Member        Yes        Yes
# 3         4         IGIHOZO Regine  Soprano     Member        Yes        Yes
# 4         5       IKIBASUMBA Diane  Soprano     Member        Yes        Yes
# ..      ...                    ...      ...        ...        ...        ...
# 115     116     UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116     117      UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 117     118      UWONKUNDA Fabiola     Alto        New        yes        Yes
# 118     119        TUYUBAHE Yvette  Soprano        New         No        Yes
# 119     120     UWIZEYE Christelle     Alto        NaN         No         No
#
# ...

# %%
Voices=CDK.groupby(['VOICE']).size()
Voices
# Out:
# VOICE
# Alto       30
# Basse      27
# Soprano    37
# Tenor      26
# dtype: int64

# %%
CDK.isna()
# Out:
#      Number  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0     False  False  False       False       False       False
# 1     False  False  False       False       False       False
# 2     False  False  False       False       False       False
# 3     False  False  False       False       False       False
# 4     False  False  False       False       False       False
# ..      ...    ...    ...         ...         ...         ...
# 115   False  False  False       False       False       False
# 116   False  False  False       False       False       False
# 117   False  False  False       False       False       False
# 118   False  False  False       False       False       False
# 119   False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
CDK.isnull()
# Out:
#      Number  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0     False  False  False       False       False       False
# 1     False  False  False       False       False       False
# 2     False  False  False       False       False       False
# 3     False  False  False       False       False       False
# 4     False  False  False       False       False       False
# ..      ...    ...    ...         ...         ...         ...
# 115   False  False  False       False       False       False
# 116   False  False  False       False       False       False
# 117   False  False  False       False       False       False
# 118   False  False  False       False       False       False
# 119   False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
#DataFrameName[DataframeName.ColumnName == ‘ValueName’] 
Alto=CDK[CDK.VOICE=='Alto']
Alto
# Out:
#      Number                         NAMES VOICE MEMBERSHIP UN_CCC2014  \
# 89       90            DUSABIMANA Liliane  Alto     Member        Yes
# 90       91      DUSINGIZIMANA Petronille  Alto     Member        Yes
# 91       92      IGIRANEZA UWAYO Chartine  Alto     Member         No
# 92       93             INGABIRE Claudine  Alto     Member         No
# 93       94         IRANKUNDA Giséle Teya  Alto     Member         No
# 94       95          IRATWIBUKA M. Salomé  Alto     Member        yes
# 95       96             IRIBAGIZA Cynthia  Alto     Member        yes
# 96       97                ISHIMWE Belyse  Alto     Member         No
# 97       98       KAYITESI Diane Patricie  Alto     Member        yes
# 98       99      MBARUSHIMANA M. Laetitia  Alto     Member        yes
# 99      100          MUGENI Oda Pascaline  Alto     Member        yes
# 100     101         MUKADUSABE Petronille  Alto     Member         no
# ...

# %%
Tenor=CDK[CDK.VOICE=='Tenor']
Tenor
# Out:
#     Number                         NAMES  VOICE MEMBERSHIP  UN_CCC2014  \
# 36      37  Abbé MANIRAHO Jean Damascène  Tenor     Member          No
# 37      38              BIGANGO Valentin  Tenor     Member          No
# 38      39               BIJYIMBU Fidèle  Tenor     Member         Yes
# 39      40             GATETE Christophe  Tenor     Member          No
# 40      41           HAKIZIMANA N Cedric  Tenor     Member         yes
# 41      42            HODARI Jean Claude  Tenor     Member         yes
# 42      43                IRAMBONA Oscar  Tenor     Member         Yes
# 43      44               KALISA Emmanuel  Tenor     Member         NaN
# 44      45            KARINGANIRE Phocas  Tenor     Member          no
# 45      46               MANISHIMWE Eric  Tenor     Member         NaN
# 46      47          MBERABAGABO Emmanuel  Tenor     Member         NaN
# 47      48             MICOMYIZA Placide  Tenor     Member         YES
# ...

# %%
Basse=CDK.groupby('VOICE').get_group('Basse')
Basse
# Out:
#     Number                        NAMES  VOICE MEMBERSHIP  UN_CCC2014  \
# 62      63       BYIRINGIRO Jean Claude  Basse     Member         Yes
# 63      64             GASANA Christian  Basse     Member          No
# 64      65               GATASHYA Isaac  Basse     Member         Yes
# 65      66        HAKIZIMANA Eric Pisco  Basse     Member          No
# 66      67            IMANIRIHO Richard  Basse     Member          no
# 67      68        ISHIMWE Thierry Henry  Basse     Member          No
# 68      69            KARANGWA Innocent  Basse     Member         yes
# 69      70         KARASIRA Yves Fabien  Basse     Member         Yes
# 70      71          MANIRAGUHA Alphonse  Basse     Member          No
# 71      72     MFITUWAMPAYE Eristarique  Basse     Member          No
# 72      73          MUVUNYI Bonaventure  Basse     Member         yes
# 73      74             MUYUMBU Innocent  Basse     Member  Incomplete
# ...

# %%
CDK.shape
# Out:
# (120, 13)

# %%
Voices=CDK.groupby(['VOICE']).size()
Voices
# Out:
# VOICE
# Alto       30
# Basse      27
# Soprano    37
# Tenor      26
# dtype: int64

# %%
CDK['UN_CCC2014'].value_counts()
# Out:
# No            45
# Yes           28
# yes           19
# no             9
# YES            4
# Incomplete     2
# Yes            1
# Yew            1
# NO             1
# Name: UN_CCC2014, dtype: int64

# %%
CDK.replace({'UN_CCC2014':{'Yes ':'Yes','Yew':'Yes','Not Fitting':'Not fitting','ok':'Yes','Yes but small':'Not fitting','not fitting ':'Not fitting','not fitting':'Not fitting','yes':'Yes','no':'No','NO':'No','YES':'Yes','Not fitting ':'Not fitting','Not fitting ':'Not fitting','incomplete':'Incomplete'}},inplace=True)
CDK['UN_CCC2014'].value_counts()
# Out:
# No            55
# Yes           53
# Incomplete     2
# Name: UN_CCC2014, dtype: int64

# %%
CDK.columns
# Out:
# Index(['Number', 'NAMES', 'VOICE', 'MEMBERSHIP', 'UN_CCC2014', 'UN_CCC2016',
#        'UMUMBRATA_CCC2017', 'FUNICULI_CCC2018', 'SEKIBI_CCC2019', 'UN_OPERA',
#        'BYAMATE_CCC2021', 'REQUIEM (all black)', 'STATUS'],
#       dtype='object')

# %%
CDK['MEMBERSHIP'].value_counts()
# Out:
# Member    117
# New         2
# Name: MEMBERSHIP, dtype: int64

# %%
CDK['UN_CCC2016'].value_counts()
# Out:
# Yes            65
# No             38
# Not fitting     6
# Incomplete      2
# Name: UN_CCC2016, dtype: int64

# %%
CDK.tail(10)
# Out:
#      Number                   NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 110     111  UMUTONIWASE Antoinette     Alto     Member        Yes        Yes
# 111     112    UWAMAHORO M. Chantal     Alto     Member        Yes        Yes
# 112     113   UWIMANA Régine Annick     Alto     Member        Yes        Yes
# 113     114         UWINEZA Solange     Alto     Member         No         No
# 114     115   UWINGABIYE Alphonsine     Alto     Member         No        Yes
# 115     116      UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116     117       UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 117     118       UWONKUNDA Fabiola     Alto        New        Yes        Yes
# 118     119         TUYUBAHE Yvette  Soprano        New         No        Yes
# 119     120      UWIZEYE Christelle     Alto        NaN         No         No
#
#     UMUMBRATA_CCC2017 FUNICULI_CCC2018 SEKIBI_CCC2019 UN_OPERA  \
# ...

# %%
voce=Voices.plot(kind='bar',xlabel='VOICES',ylabel='Number of members per voice', title='RESPONDENTS BY VOICE')
for p in voce.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    voce.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
#CDK3=pd.crosstab(CDK['VOICE'], CDK['UN_CCC2014'], margins=True)
#CDK3
CDK.isna()
# Out:
#      Number  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0     False  False  False       False       False       False
# 1     False  False  False       False       False       False
# 2     False  False  False       False       False       False
# 3     False  False  False       False       False       False
# 4     False  False  False       False       False       False
# ..      ...    ...    ...         ...         ...         ...
# 115   False  False  False       False       False       False
# 116   False  False  False       False       False       False
# 117   False  False  False       False       False       False
# 118   False  False  False       False       False       False
# 119   False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
CDK['MEMBERSHIP'].fillna('Member')
# Out:
# 0      Member
# 1      Member
# 2      Member
# 3      Member
# 4      Member
#         ...
# 115    Member
# 116    Member
# 117       New
# 118       New
# 119    Member
# Name: MEMBERSHIP, Length: 120, dtype: object

# %%
#CDK3.plot(kind='bar',xlabel='VOICES',ylabel='NUMBER OF SINGERS', title="UNIFORM2014")
CDK.isna()
# Out:
#      Number  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 0     False  False  False       False       False       False
# 1     False  False  False       False       False       False
# 2     False  False  False       False       False       False
# 3     False  False  False       False       False       False
# 4     False  False  False       False       False       False
# ..      ...    ...    ...         ...         ...         ...
# 115   False  False  False       False       False       False
# 116   False  False  False       False       False       False
# 117   False  False  False       False       False       False
# 118   False  False  False       False       False       False
# 119   False  False  False        True       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 0                False             False           False     False
# 1                False             False           False     False
# ...

# %%
CDK
# Out:
#      Number                  NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 0         1      DUKUNDE Henriette  Soprano     Member        Yes        Yes
# 1         2  DUKUZE MUGENZI Vivine  Soprano     Member        Yes        Yes
# 2         3   HITIYAREMYE Clotilde  Soprano     Member        Yes        Yes
# 3         4         IGIHOZO Regine  Soprano     Member        Yes        Yes
# 4         5       IKIBASUMBA Diane  Soprano     Member        Yes        Yes
# ..      ...                    ...      ...        ...        ...        ...
# 115     116     UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116     117      UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 117     118      UWONKUNDA Fabiola     Alto        New        Yes        Yes
# 118     119        TUYUBAHE Yvette  Soprano        New         No        Yes
# 119     120     UWIZEYE Christelle     Alto        NaN         No         No
#
# ...

# %%
CDK.isnull().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              1
# UN_CCC2014             10
# UN_CCC2016              9
# UMUMBRATA_CCC2017       8
# FUNICULI_CCC2018        1
# SEKIBI_CCC2019          2
# UN_OPERA               41
# BYAMATE_CCC2021         3
# REQUIEM (all black)     5
# STATUS                 39
# dtype: int64

# %%
CDK.isna().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              1
# UN_CCC2014             10
# UN_CCC2016              9
# UMUMBRATA_CCC2017       8
# FUNICULI_CCC2018        1
# SEKIBI_CCC2019          2
# UN_OPERA               41
# BYAMATE_CCC2021         3
# REQUIEM (all black)     5
# STATUS                 39
# dtype: int64

# %%
groups=CDK.groupby(['VOICE']).size()
groups
# Out:
# VOICE
# Alto       30
# Basse      27
# Soprano    37
# Tenor      26
# dtype: int64

# %%
UN2014=CDK.groupby(['UN_CCC2014']).size()
UN2014
# Out:
# UN_CCC2014
# Incomplete     2
# No            55
# Yes           53
# dtype: int64

# %%
tail=CDK.tail(1)
tail
# Out:
#      Number               NAMES VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 119     120  UWIZEYE Christelle  Alto        NaN         No         No
#
#     UMUMBRATA_CCC2017 FUNICULI_CCC2018 SEKIBI_CCC2019 UN_OPERA  \
# 119                No               No             No       No
#
#     BYAMATE_CCC2021 REQUIEM (all black)  STATUS
# 119             Yes                 Yes  Active

# %%
CDK["UN_CCC2014"].fillna('No', inplace = True)

# %%
CDK.isna().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              1
# UN_CCC2014              0
# UN_CCC2016              9
# UMUMBRATA_CCC2017       8
# FUNICULI_CCC2018        1
# SEKIBI_CCC2019          2
# UN_OPERA               41
# BYAMATE_CCC2021         3
# REQUIEM (all black)     5
# STATUS                 39
# dtype: int64

# %%
CDK["MEMBERSHIP"].fillna('Member', inplace = True)

# %%
CDK.isna().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              0
# UN_CCC2014              0
# UN_CCC2016              9
# UMUMBRATA_CCC2017       8
# FUNICULI_CCC2018        1
# SEKIBI_CCC2019          2
# UN_OPERA               41
# BYAMATE_CCC2021         3
# REQUIEM (all black)     5
# STATUS                 39
# dtype: int64

# %%
CDK["UN_CCC2016"].fillna('No', inplace = True)

# %%
CDK.isna().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              0
# UN_CCC2014              0
# UN_CCC2016              0
# UMUMBRATA_CCC2017       8
# FUNICULI_CCC2018        1
# SEKIBI_CCC2019          2
# UN_OPERA               41
# BYAMATE_CCC2021         3
# REQUIEM (all black)     5
# STATUS                 39
# dtype: int64

# %%
CDK["UMUMBRATA_CCC2017"].fillna('No', inplace = True)
CDK["FUNICULI_CCC2018"].fillna('No', inplace = True)
CDK["SEKIBI_CCC2019"].fillna('No', inplace = True)
CDK["UN_OPERA"].fillna('Yes', inplace = True)
CDK["BYAMATE_CCC2021"].fillna('No', inplace = True)
CDK["REQUIEM (all black)"].fillna('No', inplace = True)

# %%
CDK.isna().sum()
# Out:
# Number                  0
# NAMES                   0
# VOICE                   0
# MEMBERSHIP              0
# UN_CCC2014              0
# UN_CCC2016              0
# UMUMBRATA_CCC2017       0
# FUNICULI_CCC2018        0
# SEKIBI_CCC2019          0
# UN_OPERA                0
# BYAMATE_CCC2021         0
# REQUIEM (all black)     0
# STATUS                 39
# dtype: int64

# %%
CDK["STATUS"].fillna('Active', inplace = True)

# %%
CDK.isna().sum()
# Out:
# Number                 0
# NAMES                  0
# VOICE                  0
# MEMBERSHIP             0
# UN_CCC2014             0
# UN_CCC2016             0
# UMUMBRATA_CCC2017      0
# FUNICULI_CCC2018       0
# SEKIBI_CCC2019         0
# UN_OPERA               0
# BYAMATE_CCC2021        0
# REQUIEM (all black)    0
# STATUS                 0
# dtype: int64

# %%
UN2014=CDK.groupby(['UN_CCC2014']).size()
UN2014
# Out:
# UN_CCC2014
# Incomplete     2
# No            65
# Yes           53
# dtype: int64

# %%
CDK
# Out:
#      Number                  NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 0         1      DUKUNDE Henriette  Soprano     Member        Yes        Yes
# 1         2  DUKUZE MUGENZI Vivine  Soprano     Member        Yes        Yes
# 2         3   HITIYAREMYE Clotilde  Soprano     Member        Yes        Yes
# 3         4         IGIHOZO Regine  Soprano     Member        Yes        Yes
# 4         5       IKIBASUMBA Diane  Soprano     Member        Yes        Yes
# ..      ...                    ...      ...        ...        ...        ...
# 115     116     UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116     117      UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 117     118      UWONKUNDA Fabiola     Alto        New        Yes        Yes
# 118     119        TUYUBAHE Yvette  Soprano        New         No        Yes
# 119     120     UWIZEYE Christelle     Alto     Member         No         No
#
# ...

# %%
CDK.isna().sum()
# Out:
# Number                 0
# NAMES                  0
# VOICE                  0
# MEMBERSHIP             0
# UN_CCC2014             0
# UN_CCC2016             0
# UMUMBRATA_CCC2017      0
# FUNICULI_CCC2018       0
# SEKIBI_CCC2019         0
# UN_OPERA               0
# BYAMATE_CCC2021        0
# REQUIEM (all black)    0
# STATUS                 0
# dtype: int64

# %%
CDK['STATUS'].value_counts()
# Out:
# Active        104
# Non active     16
# Name: STATUS, dtype: int64

# %%
Voices=CDK.groupby(['VOICE']).size()
UN2014=CDK.groupby(['UN_CCC2014']).size()
UN2016=CDK.groupby(['UN_CCC2016']).size()
UN2017=CDK.groupby(['UMUMBRATA_CCC2017']).size()
UN2018=CDK.groupby(['FUNICULI_CCC2018']).size()
UN2019=CDK.groupby(['SEKIBI_CCC2019']).size()
UN_OPERA=CDK.groupby(['UN_OPERA']).size()
UN2021=CDK.groupby(['BYAMATE_CCC2021']).size()
UN_Requiem=CDK.groupby(['REQUIEM (all black)']).size()
Active_members=CDK.groupby(['STATUS']).get_group('Active')
Inactive_members=CDK.groupby(['STATUS']).get_group('Non active')

# %%
Active_members
# Out:
#      Number                  NAMES    VOICE MEMBERSHIP UN_CCC2014 UN_CCC2016  \
# 4         5       IKIBASUMBA Diane  Soprano     Member        Yes        Yes
# 5         6  INGABIRE Marie Gratia  Soprano     Member         No         No
# 6         7      IRADUKUNDA Rosine  Soprano     Member         No         No
# 7         8        ISHIMWE Cynthia  Soprano     Member         No         No
# 8         9    ISHIMWE Marie Grâce  Soprano     Member         No         No
# ..      ...                    ...      ...        ...        ...        ...
# 115     116     UWIRAGIYE Clémence     Alto     Member         No        Yes
# 116     117      UWIRAGIYE Vestine     Alto     Member        Yes        Yes
# 117     118      UWONKUNDA Fabiola     Alto        New        Yes        Yes
# 118     119        TUYUBAHE Yvette  Soprano        New         No        Yes
# 119     120     UWIZEYE Christelle     Alto     Member         No         No
#
# ...

# %%
Active_members.groupby('UN_CCC2016').get_group('Yes')
# Out:
#      Number                         NAMES    VOICE MEMBERSHIP  UN_CCC2014  \
# 4         5              IKIBASUMBA Diane  Soprano     Member         Yes
# 10       11               IZABAYO Liliane  Soprano     Member          No
# 12       13           KUBWIMANA Charlotte  Soprano     Member         Yes
# 14       15            MFURANZIZA Deodata  Soprano     Member          No
# 15       16             MUJAWIMANA Rosine  Soprano     Member         Yes
# 16       17      MUKAMAZIMPAKA Alphonsine  Soprano     Member         Yes
# 18       19          MUKESHIMANA Philmine  Soprano     Member          No
# 19       20            MUREKATETE Vestine  Soprano     Member         Yes
# 20       21         MURORUNKWERE Joie Léa  Soprano     Member         Yes
# 22       23              NISHIMWE Dévothe  Soprano     Member         Yes
# 26       27        SIMBI NDIZIHIWE Yvette  Soprano     Member         Yes
# 27       28           UMUTONIWASE Josiane  Soprano     Member          No
# ...

# %%
UN2021
# Out:
# BYAMATE_CCC2021
# Incomplete     2
# No            22
# Yes           96
# dtype: int64

# %%
Inactive_members
# Out:
#      Number                         NAMES    VOICE MEMBERSHIP UN_CCC2014  \
# 0         1             DUKUNDE Henriette  Soprano     Member        Yes
# 1         2         DUKUZE MUGENZI Vivine  Soprano     Member        Yes
# 2         3          HITIYAREMYE Clotilde  Soprano     Member        Yes
# 3         4                IGIHOZO Regine  Soprano     Member        Yes
# 17       18           MUKANKURANGA Cécile  Soprano     Member        Yes
# 23       24   NYIRANSHIMIYIMANA Christine  Soprano     Member        Yes
# 24       25  RUGWIZANGOGA UMWALI Mireille  Soprano     Member        Yes
# 34       35          UYISENGA Yvonne Josy  Soprano     Member        Yes
# 35       36          UZAMUSHAKA Séraphine  Soprano     Member         No
# 66       67             IMANIRIHO Richard    Basse     Member         No
# 69       70          KARASIRA Yves Fabien    Basse     Member        Yes
# 70       71           MANIRAGUHA Alphonse    Basse     Member         No
# ...

# %%
Voices=Active_members.groupby(['VOICE']).size()
UN2014=Active_members.groupby(['UN_CCC2014']).size()
UN2016=Active_members.groupby(['UN_CCC2016']).size()
UN2017=Active_members.groupby(['UMUMBRATA_CCC2017']).size()
UN2018=CDK.groupby(['FUNICULI_CCC2018']).size()
UN2019=Active_members.groupby(['SEKIBI_CCC2019']).size()
UN_OPERA=Active_members.groupby(['UN_OPERA']).size()
UN2021=Active_members.groupby(['BYAMATE_CCC2021']).size()
UN_Requiem=Active_members.groupby(['REQUIEM (all black)']).size()

# %%
UN_Requiem
# Out:
# REQUIEM (all black)
# Incomplete     1
# No             7
# Yes           96
# dtype: int64

# %%
Status_by_voice=pd.crosstab(CDK['VOICE'], CDK['STATUS'], margins=True)

# %%
Status=Status_by_voice.plot(kind='bar',xlabel='VOICES',ylabel='Number of members', title='RESPONDENTS STATUS')
for p in Status.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    Status.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
pd.crosstab(CDK['VOICE'], CDK['STATUS'], margins=True)
# Out:
# STATUS   Active  Non active  All
# VOICE
# Alto         26           4   30
# Basse        24           3   27
# Soprano      28           9   37
# Tenor        26           0   26
# All         104          16  120

# %%
data = [37,29,26,27]
label = ['Soprano', 'Alto', 'Tenor', 'Basse']
 
plt.pie(data, labels=label, autopct='%1.1f%%', explode=[0.1,0.1,0.1,0.1], shadow=True, startangle=90)
plt.title('RESPONDENTS BY VOICE')
plt.axis('equal')
plt.show()

# %%
Unif_2014=pd.crosstab(CDK['VOICE'], Active_members['UN_CCC2014'], margins=True)
Unif_2014
# Out:
# UN_CCC2014  Incomplete  No  Yes  All
# VOICE
# Alto                 0  14   12   26
# Basse                1  15    8   24
# Soprano              0  19    9   28
# Tenor                1  14   11   26
# All                  2  62   40  104

# %%
graph=Unif_2014.plot(kind='bar', xlabel='CHOIR',ylabel='Number of 2014 Uniform holders', title='2014 UNIFORM STATUS' )
for p in graph.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_2016=pd.crosstab(CDK['VOICE'], Active_members['UN_CCC2016'], margins=True)
Unif_2016
# Out:
# UN_CCC2016  Incomplete  No  Not fitting  Yes  All
# VOICE
# Alto                 1   5            0   20   26
# Basse                0  12            4    8   24
# Soprano              0  12            0   16   28
# Tenor                1  15            2    8   26
# All                  2  44            6   52  104

# %%
graph16=Unif_2016.plot(kind='bar', xlabel='CHOIR',ylabel='Number of 2016 Uniform holders', title='2016 UNIFORM STATUS' )
for p in graph16.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph16.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Active_members['UN_CCC2016'].nunique()
# Out:
# 4

# %%
Active_members.isna()
# Out:
#      Number  NAMES  VOICE  MEMBERSHIP  UN_CCC2014  UN_CCC2016  \
# 4     False  False  False       False       False       False
# 5     False  False  False       False       False       False
# 6     False  False  False       False       False       False
# 7     False  False  False       False       False       False
# 8     False  False  False       False       False       False
# ..      ...    ...    ...         ...         ...         ...
# 115   False  False  False       False       False       False
# 116   False  False  False       False       False       False
# 117   False  False  False       False       False       False
# 118   False  False  False       False       False       False
# 119   False  False  False       False       False       False
#
#      UMUMBRATA_CCC2017  FUNICULI_CCC2018  SEKIBI_CCC2019  UN_OPERA  \
# 4                False             False           False     False
# 5                False             False           False     False
# ...

# %%
Unif_2017=pd.crosstab(Active_members['VOICE'], Active_members['UMUMBRATA_CCC2017'], margins=True)
Unif_2017
# Out:
# UMUMBRATA_CCC2017  Incomplete  No  Not fitting  Yes  All
# VOICE
# Alto                        1  11            0   14   26
# Basse                       0   6            5   13   24
# Soprano                     0   8            0   20   28
# Tenor                       0  11            0   15   26
# All                         1  36            5   62  104

# %%
UN2017
# Out:
# UMUMBRATA_CCC2017
# Incomplete      1
# No             36
# Not fitting     5
# Yes            62
# dtype: int64

# %%
graph17=Unif_2017.plot(kind='bar',xlabel='CHOIR',ylabel='Number of "UMUMBRATA" Uniform holders', title='2017 UNIFORM STATUS')
for p in graph17.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph17.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_2018=pd.crosstab(Active_members['VOICE'], Active_members['FUNICULI_CCC2018'], margins=True)
Unif_2018
# Out:
# FUNICULI_CCC2018  Incomplete  No  Not fitting  Yes  All
# VOICE
# Alto                       0   2            0   24   26
# Basse                      1   4            4   15   24
# Soprano                    0   6            0   22   28
# Tenor                      0   7            0   19   26
# All                        1  19            4   80  104

# %%
graph18=Unif_2018.plot(kind='bar',xlabel='CHOIR',ylabel='Number of "FUNICULI" Uniform holders', title='2018 UNIFORM STATUS')
for p in graph18.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph18.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_2019=pd.crosstab(Active_members['VOICE'], Active_members['SEKIBI_CCC2019'], margins=True)
Unif_2019
# Out:
# SEKIBI_CCC2019  Incomplete  No  Yes  All
# VOICE
# Alto                     0   2   24   26
# Basse                    1   4   19   24
# Soprano                  0   4   24   28
# Tenor                    2   4   20   26
# All                      3  14   87  104

# %%
graph19=Unif_2019.plot(kind='bar',xlabel='CHOIR',ylabel='Number of "2019" Uniform holders', title='2019 UNIFORM STATUS')
for p in graph19.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph19.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_OPERA=pd.crosstab(Active_members['VOICE'], Active_members['UN_OPERA'], margins=True)
Unif_OPERA
# Out:
# UN_OPERA  Incomplete  No  Yes  All
# VOICE
# Alto               2   3   21   26
# Basse              0   2   22   24
# Soprano            2   1   25   28
# Tenor              0   1   25   26
# All                4   7   93  104

# %%
graphOP=Unif_OPERA.plot(kind='bar',xlabel='CHOIR',ylabel='Number of "OPERA" Uniform holders', title='2019 a.k.a OPERA UNIFORM STATUS')
for p in graphOP.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graphOP.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_2021=pd.crosstab(Active_members['VOICE'], Active_members['BYAMATE_CCC2021'], margins=True)
Unif_2021
# Out:
# BYAMATE_CCC2021  Incomplete  No  Yes  All
# VOICE
# Alto                      0   4   22   26
# Basse                     0   3   21   24
# Soprano                   0   1   27   28
# Tenor                     2   5   19   26
# All                       2  13   89  104

# %%
graph21=Unif_2021.plot(kind='bar',xlabel='CHOIR',ylabel='Number of 2021 Uniform holders', title='2021 UNIFORM STATUS')
for p in graph21.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graph21.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Unif_Req=pd.crosstab(Active_members['VOICE'], Active_members['REQUIEM (all black)'], margins=True)
Unif_Req
# Out:
# REQUIEM (all black)  Incomplete  No  Yes  All
# VOICE
# Alto                          0   1   25   26
# Basse                         1   0   23   24
# Soprano                       0   1   27   28
# Tenor                         0   5   21   26
# All                           1   7   96  104

# %%
graphREQ=Unif_Req.plot(kind='bar',xlabel='CHOIR',ylabel='Number of "REQUIEM" Uniform holders', title='REQUIEM EVENTS UNIFORM STATUS')
for p in graphREQ.patches:
    width=p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    graphREQ.annotate(f'{height}',(x+width/2,y+height*1.02),ha='center')

# %%
Active_members.columns
# Out:
# Index(['Number', 'NAMES', 'VOICE', 'MEMBERSHIP', 'UN_CCC2014', 'UN_CCC2016',
#        'UMUMBRATA_CCC2017', 'FUNICULI_CCC2018', 'SEKIBI_CCC2019', 'UN_OPERA',
#        'BYAMATE_CCC2021', 'REQUIEM (all black)', 'STATUS'],
#       dtype='object')

# %%
Active_members[(Active_members['UN_CCC2014']=='Yes')& (Active_members['UN_CCC2016']=='Yes') & (Active_members['UMUMBRATA_CCC2017']=='Yes')& (Active_members['FUNICULI_CCC2018']=='Yes')& (Active_members['SEKIBI_CCC2019']=='Yes')& (Active_members['UN_OPERA']=='Yes')& (Active_members['BYAMATE_CCC2021']=='Yes')& (Active_members['REQUIEM (all black)']=='Yes')]
# Out:
#      Number                     NAMES    VOICE MEMBERSHIP UN_CCC2014  \
# 12       13       KUBWIMANA Charlotte  Soprano     Member        Yes
# 15       16         MUJAWIMANA Rosine  Soprano     Member        Yes
# 16       17  MUKAMAZIMPAKA Alphonsine  Soprano     Member        Yes
# 19       20        MUREKATETE Vestine  Soprano     Member        Yes
# 20       21     MURORUNKWERE Joie Léa  Soprano     Member        Yes
# 22       23          NISHIMWE Dévothe  Soprano     Member        Yes
# 26       27    SIMBI NDIZIHIWE Yvette  Soprano     Member        Yes
# 41       42        HODARI Jean Claude    Tenor     Member        Yes
# 47       48         MICOMYIZA Placide    Tenor     Member        Yes
# 68       69         KARANGWA Innocent    Basse     Member        Yes
# 83       84      TURAYISHIMYE Léandre    Basse     Member        Yes
# 86       87           UWIMANA Patrick    Basse     Member        Yes
# 90       91  DUSINGIZIMANA Petronille     Alto     Member        Yes
# ...

# %%
Act=Active_members[(Active_members['UN_CCC2014']=='Yes')]
Act
# Out:
#      Number                     NAMES    VOICE MEMBERSHIP UN_CCC2014  \
# 4         5          IKIBASUMBA Diane  Soprano     Member        Yes
# 12       13       KUBWIMANA Charlotte  Soprano     Member        Yes
# 15       16         MUJAWIMANA Rosine  Soprano     Member        Yes
# 16       17  MUKAMAZIMPAKA Alphonsine  Soprano     Member        Yes
# 19       20        MUREKATETE Vestine  Soprano     Member        Yes
# 20       21     MURORUNKWERE Joie Léa  Soprano     Member        Yes
# 22       23          NISHIMWE Dévothe  Soprano     Member        Yes
# 26       27    SIMBI NDIZIHIWE Yvette  Soprano     Member        Yes
# 32       33         UWIMANA Pacifique  Soprano     Member        Yes
# 38       39           BIJYIMBU Fidèle    Tenor     Member        Yes
# 40       41       HAKIZIMANA N Cedric    Tenor     Member        Yes
# 41       42        HODARI Jean Claude    Tenor     Member        Yes
# 42       43            IRAMBONA Oscar    Tenor     Member        Yes
# ...
